# %% [markdown]
# ## Sales-data-analysis
#
# ym's rendition of TalkPython's "Excel to Python Course: ch8-case-study"
#
#
# ### Objective
# Given last year's sales data, and a commission budget of $1mil, we want to look at how we could structure the commission payout for the following year.
#
#
# ### Data Sources
# - 'customer_master.xlsx' contains 3 sets of data, namely customers, transactions, and sales
# - https://github.com/talkpython/excel-to-python-course/tree/master/code/ch8-case-study
#
# ### Changes
# - 16-12-2021 : Started project

# %%
import pandas as pd
import xlsxwriter
from pathlib import Path
from datetime import datetime

# %% [markdown]
# ### File Locations

# %%
today = datetime.today()
src_file = Path.cwd() / "data" / "raw" / "customer_master.xlsx"
output_file = Path.cwd() / "data" / "processed" / "customer_processed.xlsx"
report = Path.cwd() / "reports" / "report_v1.xlsx"

# %%
df_trx = pd.read_excel(src_file, sheet_name = "transactions")
df_cust = pd.read_excel(src_file, sheet_name = "customers", dtype={'zip_code':str})
df_salesagt = pd.read_excel(src_file, sheet_name = "sales")

url = "https://github.com/cphalpert/census-regions/blob/master/us%20census%20bureau%20regions%20and%20divisions.csv?raw=True"
regions = pd.read_csv(url, usecols=[1,2])

# %% [markdown]
# ### (1) Transactions

# %%
df_trx
# Out:
#      cust_num      sku  qty  list_price  discount_rate  invoice_price  \
# 0      LA6029    SW200    4       20000           0.24        15200.0
# 1      EB0265    PS501    4       30000           0.10        27000.0
# 2      EE4079    SW500    1       20000           0.36        12800.0
# 3      YR6861  ACC5144    4         400           0.12          352.0
# 4      WL5283    SW200    1       20000           0.17        16600.0
# ...       ...      ...  ...         ...            ...            ...
# 1995   XJ1430     SPB1    1        5000           0.19         4050.0
# 1996   AI9833    SW500    3       20000           0.24        15200.0
# 1997   WL5283    SW200    2       20000           0.40        12000.0
# 1998   SM6748  ACC9011   18         400           0.38          248.0
# 1999   VK4512    SPBC2    4        5000           0.37         3150.0
#
#       invoice_num       invoice_date_time  invoice_total
# 0           98105 2019-12-13 14:11:43.828        60800.0
# 1           58436 2019-06-05 23:12:47.344       108000.0
# 2           85825 2019-09-12 03:23:24.309        12800.0
# 3           46422 2019-10-10 15:02:54.590         1408.0
# 4           34838 2019-08-03 11:32:29.245        16600.0
# ...           ...                     ...            ...
# 1995        11706 2019-05-09 15:09:09.614         4050.0
# 1996        38703 2019-11-10 03:55:57.038        45600.0
# 1997        48217 2019-10-18 06:00:39.492        24000.0
# 1998        66811 2019-07-24 05:07:14.352         4464.0
# 1999        54454 2019-01-16 03:55:00.173        12600.0
#
# [2000 rows x 9 columns]

# %%
df_trx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cust_num           2000 non-null   object
#  1   sku                2000 non-null   object
#  2   qty                2000 non-null   int64
#  3   list_price         2000 non-null   int64
#  4   discount_rate      2000 non-null   float64
#  5   invoice_price      2000 non-null   float64
#  6   invoice_num        2000 non-null   int64
#  7   invoice_date_time  2000 non-null   datetime64[ns]
#  8   invoice_total      2000 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(2)
# memory usage: 140.8+ KB

# %%
prev_yr_total_sales = df_trx['invoice_total'].sum()
print(f'Total sales for previous year: ${prev_yr_total_sales:,.0f}')
# Out:
# Total sales for previous year: $126,493,662

# %%
total_com = 1_000_000
avg_com = total_com / prev_yr_total_sales
print(f'Average commission rate based on previous year\'s sale: {avg_com:.2%}')
# Out:
# Average commission rate based on previous year's sale: 0.79%

# %%
df_trx.describe()
# Out:
#                qty    list_price  discount_rate  invoice_price   invoice_num  \
# count  2000.000000   2000.000000    2000.000000    2000.000000   2000.000000
# mean      5.336000  15407.700000       0.202315   12279.542000  50350.670500
# std       6.072524   9907.746587       0.098452    8098.502539  28755.571742
# min       1.000000    400.000000       0.000000     200.000000     43.000000
# 25%       2.000000   5000.000000       0.130000    3950.000000  25356.250000
# 50%       3.000000  20000.000000       0.200000   14800.000000  50824.000000
# 75%       4.000000  20000.000000       0.270000   17600.000000  75442.000000
# max      24.000000  30000.000000       0.560000   30000.000000  99990.000000
#
#        invoice_total
# count    2000.000000
# mean    63246.831000
# std     94703.387591
# min       240.000000
# 25%     12400.000000
# 50%     32000.000000
# 75%     66450.000000
# max    705600.000000

# %%
df_trx.describe(include=object)
# Out:
#        cust_num    sku
# count      2000   2000
# unique       50     12
# top      VK4512  SW200
# freq         53    338

# %%
agg_cols = {'invoice_num' : 'count', 'discount_rate':'mean','qty':'sum', 'invoice_total':'sum'}

# %%
df_trx.groupby('sku').agg(agg_cols).reset_index()
# Out:
#         sku  invoice_num  discount_rate   qty  invoice_total
# 0   ACC0001           73       0.207671   377       118828.0
# 1   ACC5144           71       0.185493   469       151912.0
# 2   ACC8222           73       0.197123   443       139876.0
# 3   ACC9011           84       0.209167   427       133996.0
# 4     PS403          145       0.199172   662     16130700.0
# 5     PS501          149       0.201812   784     18609900.0
# 6      SPA1          137       0.195693   809      3274350.0
# 7      SPB1          137       0.193796   802      3238100.0
# 8     SPBC2          141       0.209787   708      2793600.0
# 9     SW121          320       0.203000  1631     25856400.0
# 10    SW200          338       0.206538  1681     26160400.0
# 11    SW500          332       0.203855  1879     29885600.0

# %% [markdown]
# ##### Based on the 'transactions' data, we made the below observations:
# - Total sales for the previous year was \$126,493,662.
# - Average commission rate based on the commission budget of $1mil is 0.79%.
# - There were a total of 2000 transactions, between 50 unique customers, and across 12 different products.
# - Some products were more popular than the rest.

# %% [markdown]
# ### (2) Customers

# %%
df_cust
# Out:
#                        company_name   channel zip_code             city state  \
# 0       Universal Technology Vision    retail    22910  Charlottesville    VA
# 1                  East Design Hill    retail    66546         Wakarusa    KS
# 2             Studio Pacific Galaxy    retail    79698          Abilene    TX
# 3                   Galaxy Building    retail    85275             Mesa    AZ
# 4        Resource Innovation Future    retail    97013            Canby    OR
# 5             Internet Hill Systems    retail    74360           Picher    OK
# 6          Pacific Hill Application    retail    49862         Munising    MI
# 7                    Net Electronic    retail    42631   Marshes Siding    KY
# 8          Software Bell Technology    retail    45342       Miamisburg    OH
# 9                    Innovation Net    retail    20390       Washington    DC
# 10          Innovation Software Net    retail    11789      Sound Beach    NY
# 11              Technology Net Star    retail    26070        Wellsburg    WV
# 12           Federated Virtual Star    retail    93438           Lompoc    CA
# 13  Contract Electronics Industries    retail    24153            Salem    VA
# 14                Hill Telecom Bell  reseller    70441       Greensburg    LA
# 15                    Hill Contract    retail    48184            Wayne    MI
# 16                   Data Solutions    retail    36609           Mobile    AL
# 17             Venture Construction    retail    06016      Broad Brook    CT
# 18         Architecture Application    retail    31738         Coolidge    GA
# 19            Speed Resource Vision    retail    64074         Napoleon    MO
# 20                 Star Interactive    retail    22153      Springfield    VA
# 21                  Solutions North  reseller    62520           Dawson    IL
# 22         Frontier North Universal    retail    29079            Lydia    SC
# 23         Analysis Future Provider    retail    06087       Unionville    CT
# 24                 Interactive Bell    retail    32233   Atlantic Beach    FL
# 25               Analysis Universal  reseller    15428           Dawson    PA
# 26     Hardware Adventure Universal    retail    67118          Norwich    KS
# 27                Alpha Electronics    retail    64840          Diamond    MO
# 28                 South Speed East  reseller    83856     Priest River    ID
# 29              Virtual Vision Data    retail    77501         Pasadena    TX
# 30                 Innovation Speed    retail    02493           Weston    MA
# 31                West Max Hardware  reseller    64738          Collins    MO
# 32           Telecom North Resource  reseller    28170        Wadesboro    NC
# 33             Electronic Max North  reseller    50624             Dike    IA
# 34                 Signal Hill Bell  reseller    68631          Creston    NE
# 35          Solutions Hill Hardware    retail    26570         Fairview    WV
# 36      Contract Solutions Resource    retail    39146          Pickens    MS
# 37                Solutions Pacific   partner    20570       Washington    DC
# 38          Telecom Medicine Design    retail    04097   North Yarmouth    ME
# 39              Federated Data Star    retail    29368             Mayo    SC
# 40                     Net Building    retail    25547       Pecks Mill    WV
# 41         Advanced Alpha Federated  reseller    56023          Delavan    MN
# 42        Atlantic Application Star    retail    21817        Crisfield    MD
# 43                Signal Innovation    retail    68007       Bennington    NE
# 44      Resource Adventure Internet    retail    49752          Kinross    MI
# 45              Omega Research Data   partner    32209     Jacksonville    FL
# 46              Solutions Universal  reseller    66212  Shawnee Mission    KS
# 47           Bell Frontier Resource    retail    95172         San Jose    CA
# 48            Frontier Architecture    retail    27605          Raleigh    NC
# 49          Vision People Solutions    retail    24557           Gretna    VA
#
#    account_num  total_sales
# 0       AH5590      1257912
# 1       OL0453      1158564
# 2       YR6861      1663488
# 3       AS3124      1193560
# 4       DK1362       958040
# 5       KK6153       970886
# 6       MS1866      1271136
# 7       WA1826      1101414
# 8       XJ1430       942044
# 9       NS1312      1010872
# 10      IU9782      1192852
# 11      OF9673      1398454
# 12      FF0339      1184974
# 13      GG0303      1035050
# 14      VG4175      6557928
# 15      AF4815      1612006
# 16      VJ0735      1429086
# 17      EE4079      1559544
# 18      GU9612      1020258
# 19      EB0265       746216
# 20      UM2244      1541486
# 21      QZ1799      6958500
# 22      MW1000      1435288
# 23      VK4512      1370404
# 24      BX6191      1042578
# 25      GU6442      6222564
# 26      GA3939      1163380
# 27      UJ1486      1162036
# 28      KI8637      7853376
# 29      YA6348      1440886
# 30      HB1781       974088
# 31      MH1146      8807964
# 32      RJ3363      7008576
# 33      SD6881      6548220
# 34      HC3828      9121596
# 35      MN7927      1020236
# 36      KI6467      1333056
# 37      ZJ6565      3817416
# 38      PU1364      1530912
# 39      VV3110       814596
# 40      EH2638      1324662
# 41      SM6748      6833484
# 42      SC3651       916094
# 43      BS0601      1238732
# 44      AI9833      1580248
# 45      KX0489      3185196
# 46      SA4443      6796068
# 47      LA6029      1719822
# 48      OC5697      1168464
# 49      WL5283      1299450

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  50 non-null     object
#  1   channel       50 non-null     object
#  2   zip_code      50 non-null     object
#  3   city          50 non-null     object
#  4   state         50 non-null     object
#  5   account_num   50 non-null     object
#  6   total_sales   50 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 2.9+ KB

# %%
df_cust.describe().style.format('{:,.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_83468_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >total_sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83468_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_83468_row0_col0" class="data row0 col0" >50</td>
#     </tr>
#     <tr>
#       <th id="T_83468_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_83468_row1_col0" class="data row1 col0" >2,529,873</td>
#     </tr>
#     <tr>
#       <th id="T_83468_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_83468_row2_col0" class="data row2 col0" >2,482,702</td>
#     </tr>
#     <tr>
#       <th id="T_83468_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_83468_row3_col0" class="data row3 col0" >746,216</td>
#     </tr>
#     <tr>
#       <th id="T_83468_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_83468_row4_col0" class="data row4 col0" >1,115,702</td>
#     </tr>
#     <tr>
#       <th id="T_83468_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_83468_row5_col0" class="data row5 col0" >1,328,859</td>
#     </tr>
#     <tr>
#       <th id="T_83468_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_83468_row6_col0" class="data row6 col0" >1,705,738</td>
#     </tr>
#     <tr>
#       <th id="T_83468_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_83468_row7_col0" class="data row7 col0" >9,121,596</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_cust.describe(include=object)
# Out:
#                        company_name channel zip_code    city state account_num
# count                            50      50       50      50    50          50
# unique                           50       3       50      48    31          50
# top     Universal Technology Vision  retail    22910  Dawson    VA      AH5590
# freq                              1      38        1       2     4           1

# %% [markdown]
# Here we see that there are a total of 50 companies in the dataset, all bearing different zipcodes and located across 48 cites/31 states. There are 3 sales channels, with the most common being retail, which is being used by 38 companies.

# %%
df_cust.groupby('state').agg({'company_name' : 'count', 'total_sales':'sum'}).reset_index().sort_values(by = ['total_sales'],ascending = False).style.format({'total_sales':'{:,.0f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_052f1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >company_name</th>
#       <th class="col_heading level0 col2" >total_sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_052f1_level0_row0" class="row_heading level0 row0" >18</th>
#       <td id="T_052f1_row0_col0" class="data row0 col0" >MO</td>
#       <td id="T_052f1_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_052f1_row0_col2" class="data row0 col2" >10,716,216</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row1" class="row_heading level0 row1" >21</th>
#       <td id="T_052f1_row1_col0" class="data row1 col0" >NE</td>
#       <td id="T_052f1_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_052f1_row1_col2" class="data row1 col2" >10,360,328</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_052f1_row2_col0" class="data row2 col0" >KS</td>
#       <td id="T_052f1_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_052f1_row2_col2" class="data row2 col2" >9,118,012</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row3" class="row_heading level0 row3" >20</th>
#       <td id="T_052f1_row3_col0" class="data row3 col0" >NC</td>
#       <td id="T_052f1_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_052f1_row3_col2" class="data row3 col2" >8,177,040</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_052f1_row4_col0" class="data row4 col0" >ID</td>
#       <td id="T_052f1_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_052f1_row4_col2" class="data row4 col2" >7,853,376</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_052f1_row5_col0" class="data row5 col0" >IL</td>
#       <td id="T_052f1_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_052f1_row5_col2" class="data row5 col2" >6,958,500</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row6" class="row_heading level0 row6" >17</th>
#       <td id="T_052f1_row6_col0" class="data row6 col0" >MN</td>
#       <td id="T_052f1_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_052f1_row6_col2" class="data row6 col2" >6,833,484</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row7" class="row_heading level0 row7" >12</th>
#       <td id="T_052f1_row7_col0" class="data row7 col0" >LA</td>
#       <td id="T_052f1_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_052f1_row7_col2" class="data row7 col2" >6,557,928</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_052f1_row8_col0" class="data row8 col0" >IA</td>
#       <td id="T_052f1_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_052f1_row8_col2" class="data row8 col2" >6,548,220</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row9" class="row_heading level0 row9" >26</th>
#       <td id="T_052f1_row9_col0" class="data row9 col0" >PA</td>
#       <td id="T_052f1_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_052f1_row9_col2" class="data row9 col2" >6,222,564</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row10" class="row_heading level0 row10" >29</th>
#       <td id="T_052f1_row10_col0" class="data row10 col0" >VA</td>
#       <td id="T_052f1_row10_col1" class="data row10 col1" >4</td>
#       <td id="T_052f1_row10_col2" class="data row10 col2" >5,133,898</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row11" class="row_heading level0 row11" >4</th>
#       <td id="T_052f1_row11_col0" class="data row11 col0" >DC</td>
#       <td id="T_052f1_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_052f1_row11_col2" class="data row11 col2" >4,828,288</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row12" class="row_heading level0 row12" >16</th>
#       <td id="T_052f1_row12_col0" class="data row12 col0" >MI</td>
#       <td id="T_052f1_row12_col1" class="data row12 col1" >3</td>
#       <td id="T_052f1_row12_col2" class="data row12 col2" >4,463,390</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row13" class="row_heading level0 row13" >5</th>
#       <td id="T_052f1_row13_col0" class="data row13 col0" >FL</td>
#       <td id="T_052f1_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_052f1_row13_col2" class="data row13 col2" >4,227,774</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row14" class="row_heading level0 row14" >30</th>
#       <td id="T_052f1_row14_col0" class="data row14 col0" >WV</td>
#       <td id="T_052f1_row14_col1" class="data row14 col1" >3</td>
#       <td id="T_052f1_row14_col2" class="data row14 col2" >3,743,352</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row15" class="row_heading level0 row15" >28</th>
#       <td id="T_052f1_row15_col0" class="data row15 col0" >TX</td>
#       <td id="T_052f1_row15_col1" class="data row15 col1" >2</td>
#       <td id="T_052f1_row15_col2" class="data row15 col2" >3,104,374</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row16" class="row_heading level0 row16" >3</th>
#       <td id="T_052f1_row16_col0" class="data row16 col0" >CT</td>
#       <td id="T_052f1_row16_col1" class="data row16 col1" >2</td>
#       <td id="T_052f1_row16_col2" class="data row16 col2" >2,929,948</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row17" class="row_heading level0 row17" >2</th>
#       <td id="T_052f1_row17_col0" class="data row17 col0" >CA</td>
#       <td id="T_052f1_row17_col1" class="data row17 col1" >2</td>
#       <td id="T_052f1_row17_col2" class="data row17 col2" >2,904,796</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row18" class="row_heading level0 row18" >27</th>
#       <td id="T_052f1_row18_col0" class="data row18 col0" >SC</td>
#       <td id="T_052f1_row18_col1" class="data row18 col1" >2</td>
#       <td id="T_052f1_row18_col2" class="data row18 col2" >2,249,884</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row19" class="row_heading level0 row19" >15</th>
#       <td id="T_052f1_row19_col0" class="data row19 col0" >ME</td>
#       <td id="T_052f1_row19_col1" class="data row19 col1" >1</td>
#       <td id="T_052f1_row19_col2" class="data row19 col2" >1,530,912</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row20" class="row_heading level0 row20" >0</th>
#       <td id="T_052f1_row20_col0" class="data row20 col0" >AL</td>
#       <td id="T_052f1_row20_col1" class="data row20 col1" >1</td>
#       <td id="T_052f1_row20_col2" class="data row20 col2" >1,429,086</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row21" class="row_heading level0 row21" >19</th>
#       <td id="T_052f1_row21_col0" class="data row21 col0" >MS</td>
#       <td id="T_052f1_row21_col1" class="data row21 col1" >1</td>
#       <td id="T_052f1_row21_col2" class="data row21 col2" >1,333,056</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row22" class="row_heading level0 row22" >1</th>
#       <td id="T_052f1_row22_col0" class="data row22 col0" >AZ</td>
#       <td id="T_052f1_row22_col1" class="data row22 col1" >1</td>
#       <td id="T_052f1_row22_col2" class="data row22 col2" >1,193,560</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row23" class="row_heading level0 row23" >22</th>
#       <td id="T_052f1_row23_col0" class="data row23 col0" >NY</td>
#       <td id="T_052f1_row23_col1" class="data row23 col1" >1</td>
#       <td id="T_052f1_row23_col2" class="data row23 col2" >1,192,852</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row24" class="row_heading level0 row24" >11</th>
#       <td id="T_052f1_row24_col0" class="data row24 col0" >KY</td>
#       <td id="T_052f1_row24_col1" class="data row24 col1" >1</td>
#       <td id="T_052f1_row24_col2" class="data row24 col2" >1,101,414</td>
#     </tr>
#     <tr>
#       <th id="T_052f1_level0_row25" class="row_heading level0 row25" >6</th>
#       <td id="T_052f1_row25_col0" class="data row25 col0" >GA</td>
#       <td

# %%
avg_sales_per_state = df_cust['total_sales'].sum()/df_cust['state'].nunique()
print(f'The average sales per state is ${avg_sales_per_state:,.2f}')
# Out:
# The average sales per state is $4,080,440.71

# %% [markdown]
# The states MO and NE brought in significantly more sales than the rest - more than double the average sales per state.

# %%
df_cust.sort_values(by='total_sales', ascending=False).head()
# Out:
#               company_name   channel zip_code          city state account_num  \
# 34        Signal Hill Bell  reseller    68631       Creston    NE      HC3828
# 31       West Max Hardware  reseller    64738       Collins    MO      MH1146
# 28        South Speed East  reseller    83856  Priest River    ID      KI8637
# 32  Telecom North Resource  reseller    28170     Wadesboro    NC      RJ3363
# 21         Solutions North  reseller    62520        Dawson    IL      QZ1799
#
#     total_sales
# 34      9121596
# 31      8807964
# 28      7853376
# 32      7008576
# 21      6958500

# %% [markdown]
# This is probably due to the fact that the top 2 customers are located in these 2 states. Notice also that the top 5 customers are all using the reseller channel.

# %%
channels = df_cust.groupby('channel').agg({'company_name' : 'count', 'total_sales':'sum'}).reset_index().sort_values(by = ['total_sales'],ascending = False)
channels
# Out:
#     channel  company_name  total_sales
# 1  reseller            10     72708276
# 2    retail            38     46782774
# 0   partner             2      7002612

# %%
channels['company_name'] = channels['company_name'] / channels['company_name'].sum()
channels['total_sales'] = channels['total_sales'] / channels['total_sales'].sum()
channels
# Out:
#     channel  company_name  total_sales
# 1  reseller          0.20     0.574798
# 2    retail          0.76     0.369843
# 0   partner          0.04     0.055359

# %% [markdown]
# Even though most companies (76%) uses the retail channel, the reseller channel brought in 57% of total sales.
#
# Let's see if the sales channel has any correlation with the states the companies are in.

# %%
pd.pivot_table(df_cust, 
               index = "state", 
               columns = "channel", 
               values = 'total_sales', 
               aggfunc = 'count', 
               margins = True, 
               fill_value =0)
# Out:
# channel  partner  reseller  retail  All
# state
# AL             0         0       1    1
# AZ             0         0       1    1
# CA             0         0       2    2
# CT             0         0       2    2
# DC             1         0       1    2
# FL             1         0       1    2
# GA             0         0       1    1
# IA             0         1       0    1
# ID             0         1       0    1
# IL             0         1       0    1
# KS             0         1       2    3
# KY             0         0       1    1
# LA             0         1       0    1
# MA             0         0       1    1
# MD             0         0       1    1
# ME             0         0       1    1
# MI             0         0       3    3
# MN             0         1       0    1
# MO             0         1       2    3
# MS             0         0       1    1
# NC             0         1       1    2
# NE             0         1       1    2
# NY             0         0       1    1
# OH             0         0       1    1
# OK             0         0       1    1
# OR             0         0       1    1
# PA             0         1       0    1
# SC             0         0       2    2
# TX             0         0       2    2
# VA             0         0       4    4
# WV             0         0       3    3
# All            2        10      38   50

# %%
pd.crosstab(df_cust['state'],
            df_cust['channel'],
            values = df_cust['total_sales'], 
            aggfunc = 'sum',
            normalize = 'index')
# Out:
# channel   partner  reseller    retail
# state
# AL       0.000000  0.000000  1.000000
# AZ       0.000000  0.000000  1.000000
# CA       0.000000  0.000000  1.000000
# CT       0.000000  0.000000  1.000000
# DC       0.790636  0.000000  0.209364
# FL       0.753398  0.000000  0.246602
# GA       0.000000  0.000000  1.000000
# IA       0.000000  1.000000  0.000000
# ID       0.000000  1.000000  0.000000
# IL       0.000000  1.000000  0.000000
# KS       0.000000  0.745345  0.254655
# KY       0.000000  0.000000  1.000000
# LA       0.000000  1.000000  0.000000
# MA       0.000000  0.000000  1.000000
# MD       0.000000  0.000000  1.000000
# ME       0.000000  0.000000  1.000000
# MI       0.000000  0.000000  1.000000
# MN       0.000000  1.000000  0.000000
# MO       0.000000  0.821929  0.178071
# MS       0.000000  0.000000  1.000000
# NC       0.000000  0.857104  0.142896
# NE       0.000000  0.880435  0.119565
# NY       0.000000  0.000000  1.000000
# OH       0.000000  0.000000  1.000000
# OK       0.000000  0.000000  1.000000
# OR       0.000000  0.000000  1.000000
# PA       0.000000  1.000000  0.000000
# SC       0.000000  0.000000  1.000000
# TX       0.000000  0.000000  1.000000
# VA       0.000000  0.000000  1.000000
# WV       0.000000  0.000000  1.000000

# %% [markdown]
# The 10 companies that uses the reseller channel are spread out across 10 different states. There does not seem to be any conclusive correlation between the state and the choice of sales channel.

# %% [markdown]
# ##### The observations made from the 'customers' data can be summarised as below:
# - There are 50 companies, located across 48 cities or 31 states.
# - There are 3 sales channels, namely retail, reseller, and partner.
# - While 76% of companies go through retail, the reseller channel brought in 57% of total sales volume.
# - All top 5 companies (in terms of total sales) uses the reseller channel.
# - The top 2 companies are located in MO and NE respectively, which are coincidentially also the top 2 states in terms of total sales volume.

# %% [markdown]
# ### (3) Sales agents

# %%
df_salesagt
# Out:
#   first_name last_name     region  tenure
# 0    Shannon     Muniz  NorthEast     5.6
# 1    Leonard   Malcolm       West     3.8
# 2       Mona    Sutton    Midwest     5.4
# 3     Mickey     Tyner      South     0.7

# %%
df_salesagt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  4 non-null      object
#  1   last_name   4 non-null      object
#  2   region      4 non-null      object
#  3   tenure      4 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 256.0+ bytes

# %% [markdown]
# There are a total of 4 sales agents, each covering a different region. We would like to look into the amount of sales each of them brought in.
#
# As this table does not tell us which states belong to which regions, we need the help of an external table to tell us which region each state is located. This data can be found here: https://github.com/cphalpert/census-regions/blob/master/us%20census%20bureau%20regions%20and%20divisions.csv
#
# We will add this input to the top of the file, together with the rest of the inputs.

# %%
regions
# Out:
#    State Code     Region
# 0          AK       West
# 1          AL      South
# 2          AR      South
# 3          AZ       West
# 4          CA       West
# 5          CO       West
# 6          CT  Northeast
# 7          DC      South
# 8          DE      South
# 9          FL      South
# 10         GA      South
# 11         HI       West
# 12         IA    Midwest
# 13         ID       West
# 14         IL    Midwest
# 15         IN    Midwest
# 16         KS    Midwest
# 17         KY      South
# 18         LA      South
# 19         MA  Northeast
# 20         MD      South
# 21         ME  Northeast
# 22         MI    Midwest
# 23         MN    Midwest
# 24         MO    Midwest
# 25         MS      South
# 26         MT       West
# 27         NC      South
# 28         ND    Midwest
# 29         NE    Midwest
# 30         NH  Northeast
# 31         NJ  Northeast
# 32         NM       West
# 33         NV       West
# 34         NY  Northeast
# 35         OH    Midwest
# 36         OK      South
# 37         OR       West
# 38         PA  Northeast
# 39         RI  Northeast
# 40         SC      South
# 41         SD    Midwest
# 42         TN      South
# 43         TX      South
# 44         UT       West
# 45         VA      South
# 46         VT  Northeast
# 47         WA       West
# 48         WI    Midwest
# 49         WV      South
# 50         WY       West

# %% [markdown]
# Let's rename the columns in the region table and also change the spelling of Northeast to be consistent with the dataset we are working with.

# %%
regions = regions.rename(columns={'State Code':'state', 'Region':'region'})
regions['region'] = regions['region'].str.replace("Northeast","NorthEast")
regions
# Out:
#    state     region
# 0     AK       West
# 1     AL      South
# 2     AR      South
# 3     AZ       West
# 4     CA       West
# 5     CO       West
# 6     CT  NorthEast
# 7     DC      South
# 8     DE      South
# 9     FL      South
# 10    GA      South
# 11    HI       West
# 12    IA    Midwest
# 13    ID       West
# 14    IL    Midwest
# 15    IN    Midwest
# 16    KS    Midwest
# 17    KY      South
# 18    LA      South
# 19    MA  NorthEast
# 20    MD      South
# 21    ME  NorthEast
# 22    MI    Midwest
# 23    MN    Midwest
# 24    MO    Midwest
# 25    MS      South
# 26    MT       West
# 27    NC      South
# 28    ND    Midwest
# 29    NE    Midwest
# 30    NH  NorthEast
# 31    NJ  NorthEast
# 32    NM       West
# 33    NV       West
# 34    NY  NorthEast
# 35    OH    Midwest
# 36    OK      South
# 37    OR       West
# 38    PA  NorthEast
# 39    RI  NorthEast
# 40    SC      South
# 41    SD    Midwest
# 42    TN      South
# 43    TX      South
# 44    UT       West
# 45    VA      South
# 46    VT  NorthEast
# 47    WA       West
# 48    WI    Midwest
# 49    WV      South
# 50    WY       West

# %% [markdown]
# Now we can link each customer to their sales agent.

# %%
temp = pd.merge(df_cust,regions)
temp
# Out:
#                        company_name   channel zip_code             city state  \
# 0       Universal Technology Vision    retail    22910  Charlottesville    VA
# 1   Contract Electronics Industries    retail    24153            Salem    VA
# 2                  Star Interactive    retail    22153      Springfield    VA
# 3           Vision People Solutions    retail    24557           Gretna    VA
# 4                  East Design Hill    retail    66546         Wakarusa    KS
# 5      Hardware Adventure Universal    retail    67118          Norwich    KS
# 6               Solutions Universal  reseller    66212  Shawnee Mission    KS
# 7             Studio Pacific Galaxy    retail    79698          Abilene    TX
# 8               Virtual Vision Data    retail    77501         Pasadena    TX
# 9                   Galaxy Building    retail    85275             Mesa    AZ
# 10       Resource Innovation Future    retail    97013            Canby    OR
# 11            Internet Hill Systems    retail    74360           Picher    OK
# 12         Pacific Hill Application    retail    49862         Munising    MI
# 13                    Hill Contract    retail    48184            Wayne    MI
# 14      Resource Adventure Internet    retail    49752          Kinross    MI
# 15                   Net Electronic    retail    42631   Marshes Siding    KY
# 16         Software Bell Technology    retail    45342       Miamisburg    OH
# 17                   Innovation Net    retail    20390       Washington    DC
# 18                Solutions Pacific   partner    20570       Washington    DC
# 19          Innovation Software Net    retail    11789      Sound Beach    NY
# 20              Technology Net Star    retail    26070        Wellsburg    WV
# 21          Solutions Hill Hardware    retail    26570         Fairview    WV
# 22                     Net Building    retail    25547       Pecks Mill    WV
# 23           Federated Virtual Star    retail    93438           Lompoc    CA
# 24           Bell Frontier Resource    retail    95172         San Jose    CA
# 25                Hill Telecom Bell  reseller    70441       Greensburg    LA
# 26                   Data Solutions    retail    36609           Mobile    AL
# 27             Venture Construction    retail    06016      Broad Brook    CT
# 28         Analysis Future Provider    retail    06087       Unionville    CT
# 29         Architecture Application    retail    31738         Coolidge    GA
# 30            Speed Resource Vision    retail    64074         Napoleon    MO
# 31                Alpha Electronics    retail    64840          Diamond    MO
# 32                West Max Hardware  reseller    64738          Collins    MO
# 33                  Solutions North  reseller    62520           Dawson    IL
# 34         Frontier North Universal    retail    29079            Lydia    SC
# 35              Federated Data Star    retail    29368             Mayo    SC
# 36                 Interactive Bell    retail    32233   Atlantic Beach    FL
# 37              Omega Research Data   partner    32209     Jacksonville    FL
# 38               Analysis Universal  reseller    15428           Dawson    PA
# 39                 South Speed East  reseller    83856     Priest River    ID
# 40                 Innovation Speed    retail    02493           Weston    MA
# 41           Telecom North Resource  reseller    28170        Wadesboro    NC
# 42            Frontier Architecture    retail    27605          Raleigh    NC
# 43             Electronic Max North  reseller    50624             Dike    IA
# 44                 Signal Hill Bell  reseller    68631          Creston    NE
# 45                Signal Innovation    retail    68007       Bennington    NE
# 46      Contract Solutions Resource    retail    39146          Pickens    MS
# 47          Telecom Medicine Design    retail    04097   North Yarmouth    ME
# 48         Advanced Alpha Federated  reseller    56023          Delavan    MN
# 49        Atlantic Application Star    retail    21817        Crisfield    MD
#
#    account_num  total_sales     region
# 0       AH5590      1257912      South
# 1       GG0303      1035050      South
# 2       UM2244      1541486      South
# 3       WL5283      1299450      South
# 4       OL0453      1158564    Midwest
# 5       GA3939      1163380    Midwest
# 6       SA4443      6796068    Midwest
# 7       YR6861      1663488      South
# 8       YA6348      1440886      South
# 9       AS3124      1193560       West
# 10      DK1362       958040       West
# 11      KK6153       970886      South
# 12      MS1866      1271136    Midwest
# 13      AF4815      1612006    Midwest
# 14      AI9833      1580248    Midwest
# 15      WA1826      1101414      South
# 16      XJ1430       942044    Midwest
# 17      NS1312      1010872      South
# 18      ZJ6565      3817416      South
# 19      IU9782      1192852  NorthEast
# 20      OF9673      1398454      South
# 21      MN7927      1020236      South
# 22      EH2638      1324662      South
# 23      FF0339      1184974       West
# 24      LA6029      1719822       West
# 25      VG4175      6557928      South
# 26      VJ0735      1429086      South
# 27      EE4079      1559544  NorthEast
# 28      VK4512      1370404  NorthEast
# 29      GU9612      1020258      South
# 30      EB0265       746216    Midwest
# 31      UJ1486      1162036    Midwest
# 32      MH1146      8807964    Midwest
# 33      QZ1799      6958500    Midwest
# 34      MW1000      1435288      South
# 35      VV3110       814596      South
# 36      BX6191      1042578      South
# 37      KX0489      3185196      South
# 38      GU6442      6222564  NorthEast
# 39      KI8637      7853376       West
# 40      HB1781       974088  NorthEast
# 41      RJ3363      7008576      South
# 42      OC5697      1168464      South
# 43      SD6881      6548220    Midwest
# 44      HC3828      9121596    Midwest
# 45      BS0601      1238732    Midwest
# 46      KI6467      1333056      South
# 47      PU1364      1530912  NorthEast
# 48      SM6748      6833484    Midwest
# 49      SC3651       916094      South

# %%
cust_salesagt = pd.merge(temp, df_salesagt, how='left')

# %%
cust_salesagt
# Out:
#                        company_name   channel zip_code             city state  \
# 0       Universal Technology Vision    retail    22910  Charlottesville    VA
# 1   Contract Electronics Industries    retail    24153            Salem    VA
# 2                  Star Interactive    retail    22153      Springfield    VA
# 3           Vision People Solutions    retail    24557           Gretna    VA
# 4                  East Design Hill    retail    66546         Wakarusa    KS
# 5      Hardware Adventure Universal    retail    67118          Norwich    KS
# 6               Solutions Universal  reseller    66212  Shawnee Mission    KS
# 7             Studio Pacific Galaxy    retail    79698          Abilene    TX
# 8               Virtual Vision Data    retail    77501         Pasadena    TX
# 9                   Galaxy Building    retail    85275             Mesa    AZ
# 10       Resource Innovation Future    retail    97013            Canby    OR
# 11            Internet Hill Systems    retail    74360           Picher    OK
# 12         Pacific Hill Application    retail    49862         Munising    MI
# 13                    Hill Contract    retail    48184            Wayne    MI
# 14      Resource Adventure Internet    retail    49752          Kinross    MI
# 15                   Net Electronic    retail    42631   Marshes Siding    KY
# 16         Software Bell Technology    retail    45342       Miamisburg    OH
# 17                   Innovation Net    retail    20390       Washington    DC
# 18                Solutions Pacific   partner    20570       Washington    DC
# 19          Innovation Software Net    retail    11789      Sound Beach    NY
# 20              Technology Net Star    retail    26070        Wellsburg    WV
# 21          Solutions Hill Hardware    retail    26570         Fairview    WV
# 22                     Net Building    retail    25547       Pecks Mill    WV
# 23           Federated Virtual Star    retail    93438           Lompoc    CA
# 24           Bell Frontier Resource    retail    95172         San Jose    CA
# 25                Hill Telecom Bell  reseller    70441       Greensburg    LA
# 26                   Data Solutions    retail    36609           Mobile    AL
# 27             Venture Construction    retail    06016      Broad Brook    CT
# 28         Analysis Future Provider    retail    06087       Unionville    CT
# 29         Architecture Application    retail    31738         Coolidge    GA
# 30            Speed Resource Vision    retail    64074         Napoleon    MO
# 31                Alpha Electronics    retail    64840          Diamond    MO
# 32                West Max Hardware  reseller    64738          Collins    MO
# 33                  Solutions North  reseller    62520           Dawson    IL
# 34         Frontier North Universal    retail    29079            Lydia    SC
# 35              Federated Data Star    retail    29368             Mayo    SC
# 36                 Interactive Bell    retail    32233   Atlantic Beach    FL
# 37              Omega Research Data   partner    32209     Jacksonville    FL
# 38               Analysis Universal  reseller    15428           Dawson    PA
# 39                 South Speed East  reseller    83856     Priest River    ID
# 40                 Innovation Speed    retail    02493           Weston    MA
# 41           Telecom North Resource  reseller    28170        Wadesboro    NC
# 42            Frontier Architecture    retail    27605          Raleigh    NC
# 43             Electronic Max North  reseller    50624             Dike    IA
# 44                 Signal Hill Bell  reseller    68631          Creston    NE
# 45                Signal Innovation    retail    68007       Bennington    NE
# 46      Contract Solutions Resource    retail    39146          Pickens    MS
# 47          Telecom Medicine Design    retail    04097   North Yarmouth    ME
# 48         Advanced Alpha Federated  reseller    56023          Delavan    MN
# 49        Atlantic Application Star    retail    21817        Crisfield    MD
#
#    account_num  total_sales     region first_name last_name  tenure
# 0       AH5590      1257912      South     Mickey     Tyner     0.7
# 1       GG0303      1035050      South     Mickey     Tyner     0.7
# 2       UM2244      1541486      South     Mickey     Tyner     0.7
# 3       WL5283      1299450      South     Mickey     Tyner     0.7
# 4       OL0453      1158564    Midwest       Mona    Sutton     5.4
# 5       GA3939      1163380    Midwest       Mona    Sutton     5.4
# 6       SA4443      6796068    Midwest       Mona    Sutton     5.4
# 7       YR6861      1663488      South     Mickey     Tyner     0.7
# 8       YA6348      1440886      South     Mickey     Tyner     0.7
# 9       AS3124      1193560       West    Leonard   Malcolm     3.8
# 10      DK1362       958040       West    Leonard   Malcolm     3.8
# 11      KK6153       970886      South     Mickey     Tyner     0.7
# 12      MS1866      1271136    Midwest       Mona    Sutton     5.4
# 13      AF4815      1612006    Midwest       Mona    Sutton     5.4
# 14      AI9833      1580248    Midwest       Mona    Sutton     5.4
# 15      WA1826      1101414      South     Mickey     Tyner     0.7
# 16      XJ1430       942044    Midwest       Mona    Sutton     5.4
# 17      NS1312      1010872      South     Mickey     Tyner     0.7
# 18      ZJ6565      3817416      South     Mickey     Tyner     0.7
# 19      IU9782      1192852  NorthEast    Shannon     Muniz     5.6
# 20      OF9673      1398454      South     Mickey     Tyner     0.7
# 21      MN7927      1020236      South     Mickey     Tyner     0.7
# 22      EH2638      1324662      South     Mickey     Tyner     0.7
# 23      FF0339      1184974       West    Leonard   Malcolm     3.8
# 24      LA6029      1719822       West    Leonard   Malcolm     3.8
# 25      VG4175      6557928      South     Mickey     Tyner     0.7
# 26      VJ0735      1429086      South     Mickey     Tyner     0.7
# 27      EE4079      1559544  NorthEast    Shannon     Muniz     5.6
# 28      VK4512      1370404  NorthEast    Shannon     Muniz     5.6
# 29      GU9612      1020258      South     Mickey     Tyner     0.7
# 30      EB0265       746216    Midwest       Mona    Sutton     5.4
# 31      UJ1486      1162036    Midwest       Mona    Sutton     5.4
# 32      MH1146      8807964    Midwest       Mona    Sutton     5.4
# 33      QZ1799      6958500    Midwest       Mona    Sutton     5.4
# 34      MW1000      1435288      South     Mickey     Tyner     0.7
# 35      VV3110       814596      South     Mickey     Tyner     0.7
# 36      BX6191      1042578      South     Mickey     Tyner     0.7
# 37      KX0489      3185196      South     Mickey     Tyner     0.7
# 38      GU6442      6222564  NorthEast    Shannon     Muniz     5.6
# 39      KI8637      7853376       West    Leonard   Malcolm     3.8
# 40      HB1781       974088  NorthEast    Shannon     Muniz     5.6
# 41      RJ3363      7008576      South     Mickey     Tyner     0.7
# 42      OC5697      1168464      South     Mickey     Tyner     0.7
# 43      SD6881      6548220    Midwest       Mona    Sutton     5.4
# 44      HC3828      9121596    Midwest       Mona    Sutton     5.4
# 45      BS0601      1238732    Midwest       Mona    Sutton     5.4
# 46      KI6467      1333056      South     Mickey     Tyner     0.7
# 47      PU1364      1530912  NorthEast    Shannon     Muniz     5.6
# 48      SM6748      6833484    Midwest       Mona    Sutton     5.4
# 49      SC3651       916094      South     Mickey     Tyner     0.7

# %% [markdown]
# Let's bring in the transaction data as well.

# %%
detailed_trx = pd.merge(df_trx, cust_salesagt, left_on = "cust_num", right_on = "account_num", how="left")
detailed_trx
# Out:
#      cust_num      sku  qty  list_price  discount_rate  invoice_price  \
# 0      LA6029    SW200    4       20000           0.24        15200.0
# 1      EB0265    PS501    4       30000           0.10        27000.0
# 2      EE4079    SW500    1       20000           0.36        12800.0
# 3      YR6861  ACC5144    4         400           0.12          352.0
# 4      WL5283    SW200    1       20000           0.17        16600.0
# ...       ...      ...  ...         ...            ...            ...
# 1995   XJ1430     SPB1    1        5000           0.19         4050.0
# 1996   AI9833    SW500    3       20000           0.24        15200.0
# 1997   WL5283    SW200    2       20000           0.40        12000.0
# 1998   SM6748  ACC9011   18         400           0.38          248.0
# 1999   VK4512    SPBC2    4        5000           0.37         3150.0
#
#       invoice_num       invoice_date_time  invoice_total  \
# 0           98105 2019-12-13 14:11:43.828        60800.0
# 1           58436 2019-06-05 23:12:47.344       108000.0
# 2           85825 2019-09-12 03:23:24.309        12800.0
# 3           46422 2019-10-10 15:02:54.590         1408.0
# 4           34838 2019-08-03 11:32:29.245        16600.0
# ...           ...                     ...            ...
# 1995        11706 2019-05-09 15:09:09.614         4050.0
# 1996        38703 2019-11-10 03:55:57.038        45600.0
# 1997        48217 2019-10-18 06:00:39.492        24000.0
# 1998        66811 2019-07-24 05:07:14.352         4464.0
# 1999        54454 2019-01-16 03:55:00.173        12600.0
#
#                      company_name   channel zip_code         city state  \
# 0          Bell Frontier Resource    retail    95172     San Jose    CA
# 1           Speed Resource Vision    retail    64074     Napoleon    MO
# 2            Venture Construction    retail    06016  Broad Brook    CT
# 3           Studio Pacific Galaxy    retail    79698      Abilene    TX
# 4         Vision People Solutions    retail    24557       Gretna    VA
# ...                           ...       ...      ...          ...   ...
# 1995     Software Bell Technology    retail    45342   Miamisburg    OH
# 1996  Resource Adventure Internet    retail    49752      Kinross    MI
# 1997      Vision People Solutions    retail    24557       Gretna    VA
# 1998     Advanced Alpha Federated  reseller    56023      Delavan    MN
# 1999     Analysis Future Provider    retail    06087   Unionville    CT
#
#      account_num  total_sales     region first_name last_name  tenure
# 0         LA6029      1719822       West    Leonard   Malcolm     3.8
# 1         EB0265       746216    Midwest       Mona    Sutton     5.4
# 2         EE4079      1559544  NorthEast    Shannon     Muniz     5.6
# 3         YR6861      1663488      South     Mickey     Tyner     0.7
# 4         WL5283      1299450      South     Mickey     Tyner     0.7
# ...          ...          ...        ...        ...       ...     ...
# 1995      XJ1430       942044    Midwest       Mona    Sutton     5.4
# 1996      AI9833      1580248    Midwest       Mona    Sutton     5.4
# 1997      WL5283      1299450      South     Mickey     Tyner     0.7
# 1998      SM6748      6833484    Midwest       Mona    Sutton     5.4
# 1999      VK4512      1370404  NorthEast    Shannon     Muniz     5.6
#
# [2000 rows x 20 columns]

# %% [markdown]
# Let's clean up this table by removing the unncessary columns.

# %%
final_data = detailed_trx.iloc[:,[1,2,8,9,10,13,16,17,18,19]].copy()
final_data
# Out:
#           sku  qty  invoice_total                 company_name   channel  \
# 0       SW200    4        60800.0       Bell Frontier Resource    retail
# 1       PS501    4       108000.0        Speed Resource Vision    retail
# 2       SW500    1        12800.0         Venture Construction    retail
# 3     ACC5144    4         1408.0        Studio Pacific Galaxy    retail
# 4       SW200    1        16600.0      Vision People Solutions    retail
# ...       ...  ...            ...                          ...       ...
# 1995     SPB1    1         4050.0     Software Bell Technology    retail
# 1996    SW500    3        45600.0  Resource Adventure Internet    retail
# 1997    SW200    2        24000.0      Vision People Solutions    retail
# 1998  ACC9011   18         4464.0     Advanced Alpha Federated  reseller
# 1999    SPBC2    4        12600.0     Analysis Future Provider    retail
#
#      state     region first_name last_name  tenure
# 0       CA       West    Leonard   Malcolm     3.8
# 1       MO    Midwest       Mona    Sutton     5.4
# 2       CT  NorthEast    Shannon     Muniz     5.6
# 3       TX      South     Mickey     Tyner     0.7
# 4       VA      South     Mickey     Tyner     0.7
# ...    ...        ...        ...       ...     ...
# 1995    OH    Midwest       Mona    Sutton     5.4
# 1996    MI    Midwest       Mona    Sutton     5.4
# 1997    VA      South     Mickey     Tyner     0.7
# 1998    MN    Midwest       Mona    Sutton     5.4
# 1999    CT  NorthEast    Shannon     Muniz     5.6
#
# [2000 rows x 10 columns]

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sku            2000 non-null   object
#  1   qty            2000 non-null   int64
#  2   invoice_total  2000 non-null   float64
#  3   company_name   2000 non-null   object
#  4   channel        2000 non-null   object
#  5   state          2000 non-null   object
#  6   region         2000 non-null   object
#  7   first_name     2000 non-null   object
#  8   last_name      2000 non-null   object
#  9   tenure         2000 non-null   float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 171.9+ KB

# %% [markdown]
# Let's do a brief check whether the datasets were merged correctly, by counter checking that the total sales tallies with the initial amount we had.

# %%
final_data['invoice_total'].sum() == prev_yr_total_sales
# Out:
# True

# %% [markdown]
# Earlier, we did not find any meaningful relationship between sales channel and the states the companies are located. Let's see if there is any pattern in sales channel vs region, or sales agent.

# %%
agent_vs_channel_1 = pd.pivot_table(final_data, 
                                  index = ['last_name', 'region'],
                                  columns = 'channel',
                                  values = 'company_name',
                                  aggfunc = 'nunique',
                                  margins = True,
                                  fill_value = 0)
agent_vs_channel_1
# Out:
# channel              partner  reseller  retail  All
# last_name region
# Malcolm   West             0         1       4    5
# Muniz     NorthEast        0         1       5    6
# Sutton    Midwest          0         6       9   15
# Tyner     South            2         2      20   24
# All                        2        10      38   50

# %% [markdown]
# Malcolm and Muniz appear to have notably less companies within their access, compared to Muniz and Sutton, across all channels.
#
# Tyner, who's in charge of the Southern region, appears to have significantly more companies using the retail channel compared to the other sales agents. He is also the only agent who has sales coming in via the partner channel.
#
# Sutton, on the other hand, has significantly more customers in the reseller channel compared to the other sales agents.
#
# There are 2 possibilities:
# - Agent expertise: Tyner has expertise in dealing with partner and retail customers, while Sutton's forte is targetting resellers
# - Geographical preference: The companies in the South favour the retail channel, or the companies in the Midwest favour the reseller channel
#
# With the limitations of the data we currently have, we are unable to identify which possibility is more likely. We could however, try to reorganise the sales agents' area of coverage and observe the changes in the following year's sales data.

# %% [markdown]
# Let's also look at the amount of sales generated via each channel by each sales agent.

# %%
total_sales_by_agent_and_ch1 = pd.pivot_table(final_data, 
                                           index = 'last_name', 
                                           columns = 'channel',
                                           values = 'invoice_total',
                                           aggfunc = 'sum',
                                           margins = True,
                                           fill_value = 0).style.format('{:,.0f}')
total_sales_by_agent_and_ch1
# Out:
# <style type="text/css">
# </style>
# <table id="T_b6b4f_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >channel</th>
#       <th class="col_heading level0 col0" >partner</th>
#       <th class="col_heading level0 col1" >reseller</th>
#       <th class="col_heading level0 col2" >retail</th>
#       <th class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >last_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6b4f_level0_row0" class="row_heading level0 row0" >Malcolm</th>
#       <td id="T_b6b4f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b6b4f_row0_col1" class="data row0 col1" >7,853,376</td>
#       <td id="T_b6b4f_row0_col2" class="data row0 col2" >5,056,396</td>
#       <td id="T_b6b4f_row0_col3" class="data row0 col3" >12,909,772</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4f_level0_row1" class="row_heading level0 row1" >Muniz</th>
#       <td id="T_b6b4f_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_b6b4f_row1_col1" class="data row1 col1" >6,222,564</td>
#       <td id="T_b6b4f_row1_col2" class="data row1 col2" >6,627,800</td>
#       <td id="T_b6b4f_row1_col3" class="data row1 col3" >12,850,364</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4f_level0_row2" class="row_heading level0 row2" >Sutton</th>
#       <td id="T_b6b4f_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_b6b4f_row2_col1" class="data row2 col1" >45,065,832</td>
#       <td id="T_b6b4f_row2_col2" class="data row2 col2" >10,874,362</td>
#       <td id="T_b6b4f_row2_col3" class="data row2 col3" >55,940,194</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4f_level0_row3" class="row_heading level0 row3" >Tyner</th>
#       <td id="T_b6b4f_row3_col0" class="data row3 col0" >7,002,612</td>
#       <td id="T_b6b4f_row3_col1" class="data row3 col1" >13,566,504</td>
#       <td id="T_b6b4f_row3_col2" class="data row3 col2" >24,224,216</td>
#       <td id="T_b6b4f_row3_col3" class="data row3 col3" >44,793,332</td>
#     </tr>
#     <tr>
#       <th id="T_b6b4f_level0_row4" class="row_heading level0 row4" >All</th>
#       <td id="T_b6b4f_row4_col0" class="data row4 col0" >7,002,612</td>
#       <td id="T_b6b4f_row4_col1" class="data row4 col1" >72,708,276</td>
#       <td id="T_b6b4f_row4_col2" class="data row4 col2" >46,782,774</td>
#       <td id="T_b6b4f_row4_col3" class="data row4 col3" >126,493,662</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Comparing this to the previous table, we see that there is generally a positive correlation between the number of companies and the total sales volume.
#
# Next, let's see if there is any correlation between the sales agents' tenure with the company and the amount of sales brought in.

# %%
final_data.groupby(['last_name']).agg({'invoice_total':'sum', 'tenure':'last'}).style.format({'invoice_total':'{:,.0f}', 'tenure':'{:.1f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_d244f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >invoice_total</th>
#       <th class="col_heading level0 col1" >tenure</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >last_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d244f_level0_row0" class="row_heading level0 row0" >Malcolm</th>
#       <td id="T_d244f_row0_col0" class="data row0 col0" >12,909,772</td>
#       <td id="T_d244f_row0_col1" class="data row0 col1" >3.8</td>
#     </tr>
#     <tr>
#       <th id="T_d244f_level0_row1" class="row_heading level0 row1" >Muniz</th>
#       <td id="T_d244f_row1_col0" class="data row1 col0" >12,850,364</td>
#       <td id="T_d244f_row1_col1" class="data row1 col1" >5.6</td>
#     </tr>
#     <tr>
#       <th id="T_d244f_level0_row2" class="row_heading level0 row2" >Sutton</th>
#       <td id="T_d244f_row2_col0" class="data row2 col0" >55,940,194</td>
#       <td id="T_d244f_row2_col1" class="data row2 col1" >5.4</td>
#     </tr>
#     <tr>
#       <th id="T_d244f_level0_row3" class="row_heading level0 row3" >Tyner</th>
#       <td id="T_d244f_row3_col0" class="data row3 col0" >44,793,332</td>
#       <td id="T_d244f_row3_col1" class="data row3 col1" >0.7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now let's see how much each agent would have made, assumming a flat commission rate of 0.79%.

# %%
final_data['comm_rate'] = avg_com
final_data['comm'] = round(final_data['invoice_total'] * avg_com,2)
final_data
# Out:
#           sku  qty  invoice_total                 company_name   channel  \
# 0       SW200    4        60800.0       Bell Frontier Resource    retail
# 1       PS501    4       108000.0        Speed Resource Vision    retail
# 2       SW500    1        12800.0         Venture Construction    retail
# 3     ACC5144    4         1408.0        Studio Pacific Galaxy    retail
# 4       SW200    1        16600.0      Vision People Solutions    retail
# ...       ...  ...            ...                          ...       ...
# 1995     SPB1    1         4050.0     Software Bell Technology    retail
# 1996    SW500    3        45600.0  Resource Adventure Internet    retail
# 1997    SW200    2        24000.0      Vision People Solutions    retail
# 1998  ACC9011   18         4464.0     Advanced Alpha Federated  reseller
# 1999    SPBC2    4        12600.0     Analysis Future Provider    retail
#
#      state     region first_name last_name  tenure  comm_rate    comm
# 0       CA       West    Leonard   Malcolm     3.8   0.007906  480.66
# 1       MO    Midwest       Mona    Sutton     5.4   0.007906  853.80
# 2       CT  NorthEast    Shannon     Muniz     5.6   0.007906  101.19
# 3       TX      South     Mickey     Tyner     0.7   0.007906   11.13
# 4       VA      South     Mickey     Tyner     0.7   0.007906  131.23
# ...    ...        ...        ...       ...     ...        ...     ...
# 1995    OH    Midwest       Mona    Sutton     5.4   0.007906   32.02
# 1996    MI    Midwest       Mona    Sutton     5.4   0.007906  360.49
# 1997    VA      South     Mickey     Tyner     0.7   0.007906  189.73
# 1998    MN    Midwest       Mona    Sutton     5.4   0.007906   35.29
# 1999    CT  NorthEast    Shannon     Muniz     5.6   0.007906   99.61
#
# [2000 rows x 12 columns]

# %%
agent_comm1 = final_data.groupby(['last_name']).agg({'comm':'sum'}).style.format('{:,.2f}')
agent_comm1
# Out:
# <style type="text/css">
# </style>
# <table id="T_12582_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >comm</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >last_name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12582_level0_row0" class="row_heading level0 row0" >Malcolm</th>
#       <td id="T_12582_row0_col0" class="data row0 col0" >102,058.73</td>
#     </tr>
#     <tr>
#       <th id="T_12582_level0_row1" class="row_heading level0 row1" >Muniz</th>
#       <td id="T_12582_row1_col0" class="data row1 col0" >101,589.00</td>
#     </tr>
#     <tr>
#       <th id="T_12582_level0_row2" class="row_heading level0 row2" >Sutton</th>
#       <td id="T_12582_row2_col0" class="data row2 col0" >442,236.99</td>
#     </tr>
#     <tr>
#       <th id="T_12582_level0_row3" class="row_heading level0 row3" >Tyner</th>
#       <td id="T_12582_row3_col0" class="data row3 col0" >354,115.33</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We see that assumming a flat commission rate of 0.79%, Malcolm and Muniz would make significantly less compared to Sutton and Tyner.

# %% [markdown]
# ##### Based on the sales agents' data, the following observations can be made:
# - All 4 sales agents have sales via the reseller and retail channels.
# - Malcolm and Muniz have less companies within their access, compared to Sutton and Tyner, across all channels.
# - The top sales agent, Sutton, has a much larger reseller volume compared to everyone else.
# - Tyner on the other hand, appears to have significantly more companies using the retail channel compared to the other sales agents.
# - Only Tyner has sales coming in via the partner channel.
# - Sutton also happens to be one of the longest-serving sales agent, having been with the company for 5.4 years. Apart from that, there appears to be little correlation between tenure and total sales volume for the rest of the agents.
# - Assumming a flat commission rate of 0.79%, Malcolm and Muniz would make significantly less commissions compared to Sutton and Tyner.

# %% [markdown]
# ### Next steps:
#
# - We will consider applying different commission rates to the different sales channels, based on the effort required to manage these clients.
# - We will take a closer look at the number of companies and sales volumes based on geographical distribution, and consider reorganising the sales agents' coverage areas.

# %% [markdown]
# ##### Let's save this final data table into a new excel file.

# %%
writer = pd.ExcelWriter(output_file, engine = 'xlsxwriter')
final_data.to_excel(writer, index = False, sheet_name="final_data")

workbook = writer.book
worksheet = writer.sheets['final_data']
num_format = workbook.add_format({'num_format': '#,##0.00'})
worksheet.set_column('C:C',14, num_format)
worksheet.set_column('D:D',28)
writer.close()

# %% [markdown]
# ##### We will also save the various tables into the report_v1 file for ease of performing comparisons later on.

# %%
writer = pd.ExcelWriter(report, engine = 'xlsxwriter')
agent_vs_channel_1.to_excel(writer, index = True, sheet_name="agents_channels")
total_sales_by_agent_and_ch1.to_excel(writer, index = True, sheet_name="agents_channels", startcol = 9)
agent_comm1.to_excel(writer, index = True, sheet_name="agents_comms")

workbook = writer.book

num_format = workbook.add_format({'num_format': '#,##0'})
worksheet = writer.sheets["agents_channels"]
worksheet.set_column('K:N',11, num_format)

num_format = workbook.add_format({'num_format': '#,##0.00'})
worksheet = writer.sheets["agents_comms"]
worksheet.set_column('B:B',10, num_format)

writer.close()
